# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
file = 'docs/metall_rates.csv'
df = pd.read_csv(file, decimal=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    191 non-null    object
#  1   gold    191 non-null    float64
#  2   silver  191 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.6+ KB

# %%
# ndf = pd.DataFrame()
yeardays = pd.date_range(start=pd.datetime(2020, 1, 1),
                           end=pd.datetime(2020, 10, 17))
yeardays
# Out:
# <ipython-input-133-983ed85fd4f4>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   yeardays = pd.date_range(start=pd.datetime(2020, 1, 1),
# <ipython-input-133-983ed85fd4f4>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end=pd.datetime(2020, 10, 17))
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-10-08', '2020-10-09', '2020-10-10', '2020-10-11',
#                '2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                '2020-10-16', '2020-10-17'],
#               dtype='datetime64[ns]', length=291, freq='D')

# %%
yeardays = pd.DataFrame(yeardays)
yeardays.rename(columns={0: "date"})
# yeardays.info()
# Out:
#           date
# 0   2020-01-01
# 1   2020-01-02
# 2   2020-01-03
# 3   2020-01-04
# 4   2020-01-05
# ..         ...
# 286 2020-10-13
# 287 2020-10-14
# 288 2020-10-15
# 289 2020-10-16
# 290 2020-10-17
#
# [291 rows x 1 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()

# %%
# ndf = yeardays.merge(df, on=["date"])
ndf = pd.merge(left=yeardays,
         right=df,
         on="date")
ndf

# %%
# df.sort_values(by=['date'], inplace=True, ascending=False)
df.sort_values(by=['date'], inplace=True, ascending=True)
df = df.reset_index(drop=True)

# df.index = df['date']
# df['date'].sort_values(ascending=True)
df.head(50)
# print(df.info())

# %%
df.index = yeardays

# %%
df['date'] = pd.to_datetime(df['date'])
# df.sort_values(by=['date'], inplace=True, ascending=False)
df.sort_values(by=['date'], inplace=True, ascending=True)
df = df.reset_index(drop=True)

# df.index = df['date']
# df['date'].sort_values(ascending=True)
df.head(50)
# print(df.info())
# Out:
#         date     gold  silver
# 0 2020-10-17  4783.12   61.06
# 1 2020-10-16  4740.64   59.98
# 2 2020-10-15  4711.68   60.06
# 3 2020-10-14  4772.77   61.96
# 4 2020-10-13  4754.14   62.06

# %%
# ndf = yeardays.merge(df, on=["date"])
ndf = pd.merge(left=yeardays,
         right=df,
         on="date")
ndf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-89e747fff4fa> in <module>
#       1 # ndf = yeardays.merge(df, on=["date"])
# ----> 2 ndf = pd.merge(left=yeardays,
#       3          right=df,
#       4          on="date")
#       5 ndf
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1016                         right_keys.append(rk)
#    1017                     if lk is not None:
# -> 1018                         left_keys.append(left._get_label_or_level_values(lk))
#    1019                         join_names.append(lk)
#    1020                     else:
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'date'

# %%
# df.sort_values(by=['date'], inplace=True, ascending=False)
df.sort_values(by=['date'], inplace=True, ascending=True)
df = df.reset_index(drop=True)

# df.index = df['date']
# df['date'].sort_values(ascending=True)
df.head(50)
# print(df.info())
# Out:
# <ipython-input-108-983ed85fd4f4>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   yeardays = pd.date_range(start=pd.datetime(2020, 1, 1),
# <ipython-input-108-983ed85fd4f4>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end=pd.datetime(2020, 10, 17))
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-10-08', '2020-10-09', '2020-10-10', '2020-10-11',
#                '2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                '2020-10-16', '2020-10-17'],
#               dtype='datetime64[ns]', length=291, freq='D')

# %%
df.index = yeardays
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-9ab7a967cec6> in <module>
# ----> 1 df.index = yeardays
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/CodeProjects/cbr_metall_analytics/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 191 elements, new values have 291 elements

# %%
df['date'] = pd.to_datetime(df['date'])
# df.sort_values(by=['date'], inplace=True, ascending=False)
df.sort_values(by=['date'], inplace=True, ascending=True)
df = df.reset_index(drop=True)

# df.index = df['date']
# df['date'].sort_values(ascending=True)
df.head(50)
# print(df.info())
# Out:
#          date     gold  silver
# 0  2020-01-01  3031.25   35.48
# 1  2020-01-02  3209.04   35.98
# 2  2020-01-05  4014.11   35.86
# 3  2020-01-07  4010.17   40.41
# 4  2020-01-08  4661.68   56.82
# 5  2020-01-09  4644.50   64.90
# 6  2020-01-10  4770.62   60.10
# 7  2020-01-14  3037.92   35.10
# 8  2020-01-15  3050.51   35.51
# 9  2020-01-16  3065.17   35.10
# 10 2020-01-17  3078.52   35.33
# 11 2020-01-18  3079.29   35.63
# 12 2020-01-21  3081.32   35.69
# 13 2020-01-22  3094.90   35.91
# 14 2020-01-23  3097.53   35.75
# 15 2020-01-24  3095.33   35.39
# 16 2020-01-25  3103.42   34.97
# 17 2020-01-28  3173.57   35.74
# 18 2020-01-29  3190.83   36.96
# 19 2020-01-30  3151.82   36.06
# 20 2020-01-31  3202.92   35.41
# 21 2020-02-06  3888.16   40.70
# 22 2020-02-07  4047.99   41.26
# 23 2020-02-09  4703.11   68.34
# 24 2020-02-10  4709.54   58.68
# 25 2020-02-13  3175.81   35.89
# 26 2020-02-14  3220.62   35.91
# 27 2020-02-15  3215.88   35.99
# 28 2020-02-18  3216.56   36.04
# 29 2020-02-19  3256.20   36.49
# 30 2020-02-20  3295.60   36.62
# 31 2020-02-21  3300.14   37.59
# 32 2020-02-22  3377.38   38.01
# 33 2020-02-26  3456.30   39.19
# 34 2020-02-27  3471.31   38.61
# 35 2020-02-28  3473.34   38.13
# 36 2020-02-29  3502.84   38.88
# 37 2020-03-03  3432.64   36.65
# 38 2020-03-06  3859.62   40.52
# 39 2020-03-07  4017.25   40.64
# 40 2020-03-09  4675.61   65.79
# 41 2020-03-10  4786.39   59.92
# 42 2020-03-13  3895.28   40.51
# 43 2020-03-14  3737.00   38.88
# 44 2020-03-17  3585.90   37.58
# 45 2020-03-18  3497.72   30.80
# 46 2020-03-19  3738.58   30.88
# 47 2020-03-20  3815.92   32.01
# 48 2020-03-21  3774.94   30.12
# 49 2020-03-24  3886.30   32.84

# %%
# df['formatted_date'] = pd.to_datetime(df['datetime'])
df['month'] = df['date'].apply(lambda x: x.month)
df['week'] = df['date'].apply(lambda x: x.weekofyear)

# df['month'] = df['date'].dt.month
# df['week'] = df['date'].dt.week
# df['week'] = df['date'].apply(datetime.time(df['date']).isocalendar()[1])
# df.head()

# %%
df['mean_per_week_gold'] = df.groupby('week')['gold'].transform('mean')
df['mean_per_week_silver'] = df.groupby('week')['silver'].transform('mean')
df['mean_per_month_gold'] = df.groupby('month')['gold'].transform('mean')
df['mean_per_month_silver'] = df.groupby('month')['silver'].transform('mean')
df.head(50)
# Out:
#          date     gold  silver  month  week  mean_per_week_gold  \
# 0  2020-01-01  3031.25   35.48      1     1         3418.133333
# 1  2020-01-02  3209.04   35.98      1     1         3418.133333
# 2  2020-01-05  4014.11   35.86      1     1         3418.133333
# 3  2020-01-07  4010.17   40.41      1     2         4521.742500
# 4  2020-01-08  4661.68   56.82      1     2         4521.742500
# 5  2020-01-09  4644.50   64.90      1     2         4521.742500
# 6  2020-01-10  4770.62   60.10      1     2         4521.742500
# 7  2020-01-14  3037.92   35.10      1     3         3062.282000
# 8  2020-01-15  3050.51   35.51      1     3         3062.282000
# 9  2020-01-16  3065.17   35.10      1     3         3062.282000
# 10 2020-01-17  3078.52   35.33      1     3         3062.282000
# 11 2020-01-18  3079.29   35.63      1     3         3062.282000
# 12 2020-01-21  3081.32   35.69      1     4         3094.500000
# 13 2020-01-22  3094.90   35.91      1     4         3094.500000
# 14 2020-01-23  3097.53   35.75      1     4         3094.500000
# 15 2020-01-24  3095.33   35.39      1     4         3094.500000
# 16 2020-01-25  3103.42   34.97      1     4         3094.500000
# 17 2020-01-28  3173.57   35.74      1     5         3179.785000
# 18 2020-01-29  3190.83   36.96      1     5         3179.785000
# 19 2020-01-30  3151.82   36.06      1     5         3179.785000
# 20 2020-01-31  3202.92   35.41      1     5         3179.785000
# 21 2020-02-06  3888.16   40.70      2     6         4213.086667
# 22 2020-02-07  4047.99   41.26      2     6         4213.086667
# 23 2020-02-09  4703.11   68.34      2     6         4213.086667
# 24 2020-02-10  4709.54   58.68      2     7         3580.462500
# 25 2020-02-13  3175.81   35.89      2     7         3580.462500
# 26 2020-02-14  3220.62   35.91      2     7         3580.462500
# 27 2020-02-15  3215.88   35.99      2     7         3580.462500
# 28 2020-02-18  3216.56   36.04      2     8         3289.176000
# 29 2020-02-19  3256.20   36.49      2     8         3289.176000
# 30 2020-02-20  3295.60   36.62      2     8         3289.176000
# 31 2020-02-21  3300.14   37.59      2     8         3289.176000
# 32 2020-02-22  3377.38   38.01      2     8         3289.176000
# 33 2020-02-26  3456.30   39.19      2     9         3475.947500
# 34 2020-02-27  3471.31   38.61      2     9         3475.947500
# 35 2020-02-28  3473.34   38.13      2     9         3475.947500
# 36 2020-02-29  3502.84   38.88      2     9         3475.947500
# 37 2020-03-03  3432.64   36.65      3    10         3769.836667
# 38 2020-03-06  3859.62   40.52      3    10         3769.836667
# 39 2020-03-07  4017.25   40.64      3    10         3769.836667
# 40 2020-03-09  4675.61   65.79      3    11         4273.570000
# 41 2020-03-10  4786.39   59.92      3    11         4273.570000
# 42 2020-03-13  3895.28   40.51      3    11         4273.570000
# 43 2020-03-14  3737.00   38.88      3    11         4273.570000
# 44 2020-03-17  3585.90   37.58      3    12         3682.612000
# 45 2020-03-18  3497.72   30.80      3    12         3682.612000
# 46 2020-03-19  3738.58   30.88      3    12         3682.612000
# 47 2020-03-20  3815.92   32.01      3    12         3682.612000
# 48 2020-03-21  3774.94   30.12      3    12         3682.612000
# 49 2020-03-24  3886.30   32.84      3    13         4029.470000
#
#     mean_per_week_silver  mean_per_month_gold  mean_per_month_silver
# 0              35.773333          3421.162857              39.433333
# 1              35.773333          3421.162857              39.433333
# 2              35.773333          3421.162857              39.433333
# 3              55.557500          3421.162857              39.433333
# 4              55.557500          3421.162857              39.433333
# 5              55.557500          3421.162857              39.433333
# 6              55.557500          3421.162857              39.433333
# 7              35.334000          3421.162857              39.433333
# 8              35.334000          3421.162857              39.433333
# 9              35.334000          3421.162857              39.433333
# 10             35.334000          3421.162857              39.433333
# 11             35.334000          3421.162857              39.433333
# 12             35.542000          3421.162857              39.433333
# 13             35.542000          3421.162857              39.433333
# 14             35.542000          3421.162857              39.433333
# 15             35.542000          3421.162857              39.433333
# 16             35.542000          3421.162857              39.433333
# 17             36.042500          3421.162857              39.433333
# 18             36.042500          3421.162857              39.433333
# 19             36.042500          3421.162857              39.433333
# 20             36.042500          3421.162857              39.433333
# 21             50.100000          3581.923750              41.020625
# 22             50.100000          3581.923750              41.020625
# 23             50.100000          3581.923750              41.020625
# 24             41.617500          3581.923750              41.020625
# 25             41.617500          3581.923750              41.020625
# 26             41.617500          3581.923750              41.020625
# 27             41.617500          3581.923750              41.020625
# 28             36.950000          3581.923750              41.020625
# 29             36.950000          3581.923750              41.020625
# 30             36.950000          3581.923750              41.020625
# 31             36.950000          3581.923750              41.020625
# 32             36.950000          3581.923750              41.020625
# 33             38.702500          3581.923750              41.020625
# 34             38.702500          3581.923750              41.020625
# 35             38.702500          3581.923750              41.020625
# 36             38.702500          3581.923750              41.020625
# 37             39.270000          3939.070588              38.488824
# 38             39.270000          3939.070588              38.488824
# 39             39.270000          3939.070588              38.488824
# 40             51.275000          3939.070588              38.488824
# 41             51.275000          3939.070588              38.488824
# 42             51.275000          3939.070588              38.488824
# 43             51.275000          3939.070588              38.488824
# 44             32.278000          3939.070588              38.488824
# 45             32.278000          3939.070588              38.488824
# 46             32.278000          3939.070588              38.488824
# 47             32.278000          3939.070588              38.488824
# 48             32.278000          3939.070588              38.488824
# 49             34.002000          3939.070588              38.488824

# %% [markdown]
# **Построить**
#   1. Графики из тетрадки
#   2. Из средних по месяцам взять и сравнить средние января и октября
#   3. Скользящие средние на 50 дней

# %%
df.index = df['date']
df.drop('date',axis = 1, inplace = True)
df.head(50)
# Out:
#                gold  silver  month  week  mean_per_week_gold  \
# date
# 2020-01-01  3031.25   35.48      1     1         3418.133333
# 2020-01-02  3209.04   35.98      1     1         3418.133333
# 2020-01-05  4014.11   35.86      1     1         3418.133333
# 2020-01-07  4010.17   40.41      1     2         4521.742500
# 2020-01-08  4661.68   56.82      1     2         4521.742500
# 2020-01-09  4644.50   64.90      1     2         4521.742500
# 2020-01-10  4770.62   60.10      1     2         4521.742500
# 2020-01-14  3037.92   35.10      1     3         3062.282000
# 2020-01-15  3050.51   35.51      1     3         3062.282000
# 2020-01-16  3065.17   35.10      1     3         3062.282000
# 2020-01-17  3078.52   35.33      1     3         3062.282000
# 2020-01-18  3079.29   35.63      1     3         3062.282000
# 2020-01-21  3081.32   35.69      1     4         3094.500000
# 2020-01-22  3094.90   35.91      1     4         3094.500000
# 2020-01-23  3097.53   35.75      1     4         3094.500000
# 2020-01-24  3095.33   35.39      1     4         3094.500000
# 2020-01-25  3103.42   34.97      1     4         3094.500000
# 2020-01-28  3173.57   35.74      1     5         3179.785000
# 2020-01-29  3190.83   36.96      1     5         3179.785000
# 2020-01-30  3151.82   36.06      1     5         3179.785000
# 2020-01-31  3202.92   35.41      1     5         3179.785000
# 2020-02-06  3888.16   40.70      2     6         4213.086667
# 2020-02-07  4047.99   41.26      2     6         4213.086667
# 2020-02-09  4703.11   68.34      2     6         4213.086667
# 2020-02-10  4709.54   58.68      2     7         3580.462500
# 2020-02-13  3175.81   35.89      2     7         3580.462500
# 2020-02-14  3220.62   35.91      2     7         3580.462500
# 2020-02-15  3215.88   35.99      2     7         3580.462500
# 2020-02-18  3216.56   36.04      2     8         3289.176000
# 2020-02-19  3256.20   36.49      2     8         3289.176000
# 2020-02-20  3295.60   36.62      2     8         3289.176000
# 2020-02-21  3300.14   37.59      2     8         3289.176000
# 2020-02-22  3377.38   38.01      2     8         3289.176000
# 2020-02-26  3456.30   39.19      2     9         3475.947500
# 2020-02-27  3471.31   38.61      2     9         3475.947500
# 2020-02-28  3473.34   38.13      2     9         3475.947500
# 2020-02-29  3502.84   38.88      2     9         3475.947500
# 2020-03-03  3432.64   36.65      3    10         3769.836667
# 2020-03-06  3859.62   40.52      3    10         3769.836667
# 2020-03-07  4017.25   40.64      3    10         3769.836667
# 2020-03-09  4675.61   65.79      3    11         4273.570000
# 2020-03-10  4786.39   59.92      3    11         4273.570000
# 2020-03-13  3895.28   40.51      3    11         4273.570000
# 2020-03-14  3737.00   38.88      3    11         4273.570000
# 2020-03-17  3585.90   37.58      3    12         3682.612000
# 2020-03-18  3497.72   30.80      3    12         3682.612000
# 2020-03-19  3738.58   30.88      3    12         3682.612000
# 2020-03-20  3815.92   32.01      3    12         3682.612000
# 2020-03-21  3774.94   30.12      3    12         3682.612000
# 2020-03-24  3886.30   32.84      3    13         4029.470000
#
#             mean_per_week_silver  mean_per_month_gold  mean_per_month_silver
# date
# 2020-01-01             35.773333          3421.162857              39.433333
# 2020-01-02             35.773333          3421.162857              39.433333
# 2020-01-05             35.773333          3421.162857              39.433333
# 2020-01-07             55.557500          3421.162857              39.433333
# 2020-01-08             55.557500          3421.162857              39.433333
# 2020-01-09             55.557500          3421.162857              39.433333
# 2020-01-10             55.557500          3421.162857              39.433333
# 2020-01-14             35.334000          3421.162857              39.433333
# 2020-01-15             35.334000          3421.162857              39.433333
# 2020-01-16             35.334000          3421.162857              39.433333
# 2020-01-17             35.334000          3421.162857              39.433333
# 2020-01-18             35.334000          3421.162857              39.433333
# 2020-01-21             35.542000          3421.162857              39.433333
# 2020-01-22             35.542000          3421.162857              39.433333
# 2020-01-23             35.542000          3421.162857              39.433333
# 2020-01-24             35.542000          3421.162857              39.433333
# 2020-01-25             35.542000          3421.162857              39.433333
# 2020-01-28             36.042500          3421.162857              39.433333
# 2020-01-29             36.042500          3421.162857              39.433333
# 2020-01-30             36.042500          3421.162857              39.433333
# 2020-01-31             36.042500          3421.162857              39.433333
# 2020-02-06             50.100000          3581.923750              41.020625
# 2020-02-07             50.100000          3581.923750              41.020625
# 2020-02-09             50.100000          3581.923750              41.020625
# 2020-02-10             41.617500          3581.923750              41.020625
# 2020-02-13             41.617500          3581.923750              41.020625
# 2020-02-14             41.617500          3581.923750              41.020625
# 2020-02-15             41.617500          3581.923750              41.020625
# 2020-02-18             36.950000          3581.923750              41.020625
# 2020-02-19             36.950000          3581.923750              41.020625
# 2020-02-20             36.950000          3581.923750              41.020625
# 2020-02-21             36.950000          3581.923750              41.020625
# 2020-02-22             36.950000          3581.923750              41.020625
# 2020-02-26             38.702500          3581.923750              41.020625
# 2020-02-27             38.702500          3581.923750              41.020625
# 2020-02-28             38.702500          3581.923750              41.020625
# 2020-02-29             38.702500          3581.923750              41.020625
# 2020-03-03             39.270000          3939.070588              38.488824
# 2020-03-06             39.270000          3939.070588              38.488824
# 2020-03-07             39.270000          3939.070588              38.488824
# 2020-03-09             51.275000          3939.070588              38.488824
# 2020-03-10             51.275000          3939.070588              38.488824
# 2020-03-13             51.275000          3939.070588              38.488824
# 2020-03-14             51.275000          3939.070588              38.488824
# 2020-03-17             32.278000          3939.070588              38.488824
# 2020-03-18             32.278000          3939.070588              38.488824
# 2020-03-19             32.278000          3939.070588              38.488824
# 2020-03-20             32.278000          3939.070588              38.488824
# 2020-03-21             32.278000          3939.070588              38.488824
# 2020-03-24             34.002000          3939.070588              38.488824

# %%
df.columns
# Out:
# Index(['gold', 'silver', 'month', 'week', 'mean_per_week_gold',
#        'mean_per_week_silver', 'mean_per_month_gold', 'mean_per_month_silver'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# gold
# silver
# month
# week
# mean_per_week_gold
# mean_per_week_silver
# mean_per_month_gold
# mean_per_month_silver

# %%
silver_list = ['silver', 'mean_per_week_silver', 'mean_per_month_silver']
gold_list = ['gold', 'mean_per_week_gold', 'mean_per_month_gold']

# %%
def plot_for_list(metall_list):
    for i in metall_list:
        df[i].plot(figsize=(20,6))

# %%
plot_for_list(silver_list)

# %%
plot_for_list(gold_list)

# %%
df.to_csv('docs/drags.csv')
